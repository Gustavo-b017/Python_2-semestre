# %%
class myClass:
    MyVar = 0

# %%
MyInstance = myClass()

# %%
MyInstance.__class__
# Out:
# __main__.myClass

# %%
class MyClass:
   def SayHello():
      print("Hello")

# %%
MyInstance = MyClass()
MyClass.SayHello()
# Out:
# Hello

# %%
class MyClass:
    Greetings = ""

    def __init__(self, Name = 'there'):
        self.Greetings = Name + '!'

    def SayHello(self):
      print("Hello, {0}".format(self.Greetings))

# %%
MyInstance = MyClass()

MyInstance.SayHello()
# Out:
# Hello, there!

# %%
MyInstance2 = MyClass('20TeComer70Correr')

MyInstance2.SayHello()
# Out:
# Hello, 20TeComer70Correr!

# %%
MyInstance.Greetings = "Harry"
MyInstance.SayHello()
# Out:
# Hello, Harry

# %%
class Cachorro:

    def __init__(self, nome, idade):
        self.nome = nome
        self.idade = idade

    def sentar (self):
        # simula um cachoro sentando
        print(f'{self.nome} esta sentado')
    
    def rolar(self):
        print(f'{self.nome} rolou')

# %%
c1 = Cachorro("Luffy", 4)
c2 = Cachorro('Saitama', 6)
print(f'o nome do cachorro 1 é {c1.nome}')
print(f'a idade do cachorro 1 é {c1.idade}')

print(f'\no nome do cachorro 2 é {c2.nome}')
print(f'a idade do cachorro 2 é {c2.idade}\n')

c1.sentar()
c1.rolar()

print('\n')

c2.sentar()
c2.rolar()
# Out:
# o nome do cachorro 1 é Luffy
# a idade do cachorro 1 é 4
#
# o nome do cachorro 2 é Saitama
# a idade do cachorro 2 é 6
#
# Luffy esta sentado
# Luffy rolou
#
#
# Saitama esta sentado
# Saitama rolou

# %%
class Conta:
    def __init__(self, quantia):
        self.saldo = quantia

    def Levantamento (self, quantia):
        if self.saldo - quantia >= 0:
            self.saldo -= quantia
            return self.saldo      
        else:
            print('\nsaldo insuficiente')

    def Deposito(self, quantia):
        self.saldo += quantia
        return self.saldo
    
    def consulta(self):

        if self.saldo <= 100:
            print('ta pobre, pq vc so tem:', self.saldo)

        else:
            return self.saldo

# %%
conta1 = Conta(100)
conta1.consulta()

conta1.Deposito(50)
print('\nsaldo após deposito: ', conta1.consulta())

conta1.Levantamento(30)
print('\nsaldo após levantamento: ', conta1.consulta())

conta1.Levantamento(200)
# Out:
# ta pobre, pq vc so tem: 100
#
# saldo após deposito:  150
#
# saldo após levantamento:  120
#
# saldo insuficiente

# %%
class Restaurante:
    def __init__(self, restaurante_nome, cozinha_tipo):
        self.restaurante_nome = restaurante_nome
        self.cozinha_tipo = cozinha_tipo

    def descricao_restaurante(self):
        print('o nome do restaurante é:', self.restaurante_nome)
        print('\no tipo de cozinha é:', self.cozinha_tipo)

    def Open_restaurante(self):
        print("O restaurante", self.restaurante_nome, " está aberto!")

# %%
restaurante = Restaurante('tranqueira da rua', 'indiana')

print('o nome do restaurante é: ', restaurante.restaurante_nome)
print('o tipo de comida do restaurante é: ', restaurante.cozinha_tipo, '\nhttps://th.bing.com/th?id=OVP.65eRwwxCxivx8zcU1d7X3wEsDh&w=243&h=136&c=7&rs=1&qlt=90&o=5&pid=2.1')
# Out:
# o nome do restaurante é:  tranqueira da rua
# o tipo de comida do restaurante é:  indiana
# https://th.bing.com/th?id=OVP.65eRwwxCxivx8zcU1d7X3wEsDh&w=243&h=136&c=7&rs=1&qlt=90&o=5&pid=2.1

# %%
import pandas as pd

# %%
df = pd.read_csv('./manutencao_preditiva.csv')
df
# Out:
#         UDI ID Produto Tipo  Temperatura Ar [K]  Temperatura Processo [K]  \
# 0         1     M14860    M               298.1                     308.6
# 1         2     L47181    L               298.2                     308.7
# 2         3     L47182    L               298.1                     308.5
# 3         4     L47183    L               298.2                     308.6
# 4         5     L47184    L               298.2                     308.7
# ...     ...        ...  ...                 ...                       ...
# 9995   9996     M24855    M               298.8                     308.4
# 9996   9997     H39410    H               298.9                     308.4
# 9997   9998     M24857    M               299.0                     308.6
# 9998   9999     H39412    H               299.0                     308.7
# 9999  10000     M24859    M               299.0                     308.7
#
#       Velocidade Rotacao [rpm]  Torque [Nm]  Desgaste Ferramenta [min]  Alvo  \
# 0                         1551         42.8                          0     0
# 1                         1408         46.3                          3     0
# 2                         1498         49.4                          5     0
# 3                         1433         39.5                          7     0
# 4                         1408         40.0                          9     0
# ...                        ...          ...                        ...   ...
# 9995                      1604         29.5                         14     0
# 9996                      1632         31.8                         17     0
# 9997                      1645         33.4                         22     0
# 9998                      1408         48.5                         25     0
# 9999                      1500         40.2                         30     0
#
#      Tipo da Falha
# 0       No Failure
# 1       No Failure
# 2       No Failure
# 3       No Failure
# 4       No Failure
# ...            ...
# 9995    No Failure
# 9996    No Failure
# 9997    No Failure
# 9998    No Failure
# 9999    No Failure
#
# [10000 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['UDI', 'ID Produto', 'Tipo', 'Temperatura Ar [K]',
#        'Temperatura Processo [K]', 'Velocidade Rotacao [rpm]', 'Torque [Nm]',
#        'Desgaste Ferramenta [min]', 'Alvo', 'Tipo da Falha'],
#       dtype='object')

# %%
pip install scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: scikit-learn in c:\python311\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\python311\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\python311\lib\site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\python311\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python311\lib\site-packages (from scikit-learn) (3.5.0)
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dados_treino = ['maca','banana','maca','laranja']
dados_transformado = le.fit_transform(dados_treino)
dados_transformado
# Out:
# array([2, 0, 2, 1], dtype=int64)

# %%
df['Tipo'] = le.fit_transform(df['Tipo'].values)
df
# Out:
#         UDI ID Produto  Tipo  Temperatura Ar [K]  Temperatura Processo [K]  \
# 0         1     M14860     2               298.1                     308.6
# 1         2     L47181     1               298.2                     308.7
# 2         3     L47182     1               298.1                     308.5
# 3         4     L47183     1               298.2                     308.6
# 4         5     L47184     1               298.2                     308.7
# ...     ...        ...   ...                 ...                       ...
# 9995   9996     M24855     2               298.8                     308.4
# 9996   9997     H39410     0               298.9                     308.4
# 9997   9998     M24857     2               299.0                     308.6
# 9998   9999     H39412     0               299.0                     308.7
# 9999  10000     M24859     2               299.0                     308.7
#
#       Velocidade Rotacao [rpm]  Torque [Nm]  Desgaste Ferramenta [min]  Alvo  \
# 0                         1551         42.8                          0     0
# 1                         1408         46.3                          3     0
# 2                         1498         49.4                          5     0
# 3                         1433         39.5                          7     0
# 4                         1408         40.0                          9     0
# ...                        ...          ...                        ...   ...
# 9995                      1604         29.5                         14     0
# 9996                      1632         31.8                         17     0
# 9997                      1645         33.4                         22     0
# 9998                      1408         48.5                         25     0
# 9999                      1500         40.2                         30     0
#
#      Tipo da Falha
# 0       No Failure
# 1       No Failure
# 2       No Failure
# 3       No Failure
# 4       No Failure
# ...            ...
# 9995    No Failure
# 9996    No Failure
# 9997    No Failure
# 9998    No Failure
# 9999    No Failure
#
# [10000 rows x 10 columns]

# %%
x = df[['Tipo', 'Temperatura Ar [K]','Temperatura Processo [K]', 'Velocidade Rotacao [rpm]', 'Torque [Nm]','Desgaste Ferramenta [min]']]

y = df['Tipo da Falha']

# %%
x
# Out:
#       Tipo  Temperatura Ar [K]  Temperatura Processo [K]  \
# 0        2               298.1                     308.6
# 1        1               298.2                     308.7
# 2        1               298.1                     308.5
# 3        1               298.2                     308.6
# 4        1               298.2                     308.7
# ...    ...                 ...                       ...
# 9995     2               298.8                     308.4
# 9996     0               298.9                     308.4
# 9997     2               299.0                     308.6
# 9998     0               299.0                     308.7
# 9999     2               299.0                     308.7
#
#       Velocidade Rotacao [rpm]  Torque [Nm]  Desgaste Ferramenta [min]
# 0                         1551         42.8                          0
# 1                         1408         46.3                          3
# 2                         1498         49.4                          5
# 3                         1433         39.5                          7
# 4                         1408         40.0                          9
# ...                        ...          ...                        ...
# 9995                      1604         29.5                         14
# 9996                      1632         31.8                         17
# 9997                      1645         33.4                         22
# 9998                      1408         48.5                         25
# 9999                      1500         40.2                         30
#
# [10000 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

xtreino, xteste, ytreino, yteste = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(100,50), max_iter=100, random_state=1)

# %%
treino = mlp.fit(xtreino, ytreino)
treino
# Out:
# MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=100, random_state=1)

# %%
predict = mlp.predict(xteste)
predict
# Out:
# array(['No Failure', 'No Failure', 'No Failure', ..., 'No Failure',
#        'No Failure', 'No Failure'], dtype='<U24')
